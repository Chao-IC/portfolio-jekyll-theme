# %%
import pandas as pd

# %%
sales = pd.read_csv('Auto_Sales_data.csv', index_col = 0)

# %%
sales_modified = sales.drop(['ORDERLINENUMBER','CUSTOMERNAME','PHONE','ADDRESSLINE1','POSTALCODE','CONTACTLASTNAME','CONTACTFIRSTNAME'], axis=1)

# %%
sales_modified.head()
# Out:
#              QUANTITYORDERED  PRICEEACH    SALES   ORDERDATE  \
# ORDERNUMBER
# 10107                     30      95.70  2871.00  24/02/2018
# 10121                     34      81.35  2765.90  07/05/2018
# 10134                     41      94.74  3884.34  01/07/2018
# 10145                     45      83.26  3746.70  25/08/2018
# 10168                     36      96.66  3479.76  28/10/2018
#
#              DAYS_SINCE_LASTORDER   STATUS  PRODUCTLINE  MSRP PRODUCTCODE  \
# ORDERNUMBER
# 10107                         828  Shipped  Motorcycles    95    S10_1678
# 10121                         757  Shipped  Motorcycles    95    S10_1678
# 10134                         703  Shipped  Motorcycles    95    S10_1678
# 10145                         649  Shipped  Motorcycles    95    S10_1678
# 10168                         586  Shipped  Motorcycles    95    S10_1678
#
#                    CITY COUNTRY DEALSIZE
# ORDERNUMBER
# 10107               NYC     USA    Small
# 10121             Reims  France    Small
# 10134             Paris  France   Medium
# 10145          Pasadena     USA   Medium
# 10168        Burlingame     USA   Medium

# %%
print(sales_modified.notnull().sum())
# Out:
# QUANTITYORDERED         2747
# PRICEEACH               2747
# SALES                   2747
# ORDERDATE               2747
# DAYS_SINCE_LASTORDER    2747
# STATUS                  2747
# PRODUCTLINE             2747
# MSRP                    2747
# PRODUCTCODE             2747
# CITY                    2747
# COUNTRY                 2747
# DEALSIZE                2747
# dtype: int64

# %%
print(sales_modified.columns.tolist())
# Out:
# ['QUANTITYORDERED', 'PRICEEACH', 'SALES', 'ORDERDATE', 'DAYS_SINCE_LASTORDER', 'STATUS', 'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CITY', 'COUNTRY', 'DEALSIZE']

# %%
indicater = pd.read_csv('e22f2293-f590-46c3-91df-5eea2aeed022_Data.csv', index_col = 0)

# %%
indicater.head()
# Out:
#              Country Code                                        Series Name  \
# Country Name
# Afghanistan           AFG  Access to clean fuels and technologies for coo...
# Afghanistan           AFG  Access to clean fuels and technologies for coo...
# Afghanistan           AFG  Access to clean fuels and technologies for coo...
# Afghanistan           AFG            Access to electricity (% of population)
# Afghanistan           AFG  Access to electricity, rural (% of rural popul...
#
#                     Series Code 2018 [YR2018] 2019 [YR2019] 2020 [YR2020]
# Country Name
# Afghanistan      EG.CFT.ACCS.ZS          31.4          32.6          33.8
# Afghanistan   EG.CFT.ACCS.RU.ZS          14.5          15.6          16.4
# Afghanistan   EG.CFT.ACCS.UR.ZS          82.6          83.2          83.8
# Afghanistan      EG.ELC.ACCS.ZS          93.4          97.7          97.7
# Afghanistan   EG.ELC.ACCS.RU.ZS          91.6          97.1          97.1

# %%
indicater.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 401399 entries, Afghanistan to Last Updated: 04/15/2025
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Country Code   401394 non-null  object
#  1   Series Name    401394 non-null  object
#  2   Series Code    401394 non-null  object
#  3   2018 [YR2018]  401394 non-null  object
#  4   2019 [YR2019]  401394 non-null  object
#  5   2020 [YR2020]  401394 non-null  object
# dtypes: object(6)
# memory usage: 21.4+ MB

# %%
print(indicater.columns.tolist())
# Out:
# ['Country Code', 'Series Name', 'Series Code', '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]']
